# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import pymystem3
import pymorphy2
import nltk
from nltk.stem.snowball import RussianStemmer
import re
from collections import Counter

from tqdm import tqdm_notebook, tqdm
tqdm.pandas(desc="apply progress bar")

from nltk.corpus import stopwords
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

from nltk.corpus import brown

import urllib
from bs4 import BeautifulSoup

# %%
with urllib.request.urlopen('http://ezoport.ru/nauki/psixologiya/luiza-xej-tablica-prichin-boleznej-i-zabolevanij-affirmacii-zdorovya.html') as response:
    html = response.read().decode('utf-8')
bs_html = BeautifulSoup(html, "lxml")

full_table = pd.DataFrame({'disease':[], 'fealings': [], 'thinking': []})

disease_list = []
fealings_list = []
thinking_list = []
for i, row in enumerate(bs_html.find_all('tr')):
    try:
        und_rows = row.find_all('td')
        disease = und_rows[0].find_all('strong')[0].text
        
        final_disease = ''
        for word in nltk.word_tokenize(disease):
            if word != '.':
                final_disease += (' ' + word)
        final_disease = final_disease[1:]
        
        feal = und_rows[1].text
        think = und_rows[2].text
        if final_disease != 'ПРОБЛЕМА':
            full_table = full_table.append(pd.DataFrame({'disease': [final_disease],
                                                         'fealings': [feal],
                                                         'thinking': [think]}))
    except:
        # not diseases
        pass
full_table.drop_duplicates('disease', inplace=True)
full_table = full_table.reset_index().drop('index', axis=1)



with urllib.request.urlopen('https://illness.docdoc.ru') as response:
    html = response.read().decode('utf-8')
bs_html = BeautifulSoup(html, "lxml")

link_table = pd.DataFrame({'disease': [], 'link': []})

for row in bs_html.find_all('a'):
    try:
        title = row.attrs['title']
        
        final_title = ''
        for word in nltk.word_tokenize(title):
            if word != '.':
                final_title += (' ' + word)
        final_title = final_title[1:]
        
        link = row.attrs['href']
        if link[:15] != 'https://docdoc.':
            link_table = link_table.append(pd.DataFrame({'disease': [final_title], 'link': [link]}))
    except:
        # not diseases
        pass
link_table.drop_duplicates('disease', inplace=True)
link_table = link_table.reset_index().drop('index', axis=1)

# %%
link_table = link_table.merge(full_table, how='left', left_on='disease', right_on='disease')

list_of_lists = []
for i in tqdm(range(link_table.shape[0])):
    current_s_list = []
    current_link = link_table.iloc[i].link
    with urllib.request.urlopen('https://illness.docdoc.ru' + current_link) as response:
        html = response.read().decode('utf-8')
    bs_html = BeautifulSoup(html, "lxml")
    for sent in bs_html.find_all('ul')[3].find_all('li'):
        current_s_list.append(sent.text)
    list_of_lists.append(current_s_list)

# %%
link_table['symptoms'] = list_of_lists
link_table.drop('link', axis=1, inplace=True)

# %%
punctuation_mine = '!"#$%&\'()*+-./:<=>?@[\\]^_`{|}~'

from tqdm import tqdm_notebook, tqdm
tqdm.pandas(desc="apply progress bar")
from string import punctuation

def clear_symptoms(x):
    clear_text = ''
    current_x = ' '.join(x)
    for sym in current_x:
        if sym not in punctuation_mine:
            clear_text += sym
    return clear_text

link_table['clear_text'] = link_table['symptoms'].progress_apply(clear_symptoms)

# %%
link_table.to_csv('./RoboMed/out.csv', encoding='utf-8')

# %%
def add_ngrams(list_of_ends):
        list_of_ngramms = []
        for i in range(len(list_of_ends[-1])):
            list_of_ngramms.append(tuple(list_of_ends[j][i] for j in range(len(list_of_ends))))
        return Counter(list_of_ngramms)

# %%
class NGramStorage:
    """Storage for ngrams' frequencies.
    Args:
        sents (list[list[str]]): List of sentences from which ngram
            frequencies are extracted.
        max_n (int): Upper bound of the length of ngrams.
            For instance if max_n = 2, then storage will store
            0, 1, 2-grams.    
    Attributes:
        max_n (Readonly(int)): Upper bound of the length of ngrams.
    """
       
    
    def add_ngrams(self, list_of_ends):
        list_of_ngramms = []
        for i in range(len(list_of_ends[-1])):
            list_of_ngramms.append(tuple(list_of_ends[j][i] for j in range(len(list_of_ends))))
        return Counter(list_of_ngramms)
            
    
    def __init__(self, sents=[], max_n=0):
        self.__max_n = max_n
        self.__ngrams = {i: Counter() for i in range(self.__max_n + 1)}
        
        # self._ngrams[K] should have the following interface:
        # self._ngrams[K][(w_1, ..., w_K)] = number of times w_1, ..., w_K occured in words
        # self._ngrams[0][()] = number of all words
        
        self.__ngrams[0][()] = np.sum([len(sents[i]) for i in range(len(sents))])
        tokens = [' '.join(sents[i]) for i in range(len(sents))]
        tokens = (' '.join(tokens)).split(' ')
        list_of_ends = []
        list_of_ends.append(tokens)
        for n in range(1, self.__max_n + 1):
            self.__ngrams[n] = add_ngrams(list_of_ends)
            list_of_ends.append(tokens[n:])
    
    def ret_ngrams(self):
        return self.__ngrams


    def add_unk_token(self):
        """Add UNK token to 1-grams."""
        # In order to avoid zero probabilites 
        if self.__max_n == 0 or 'UNK' in self.__ngrams[1]:
            return
        self.__ngrams[0][()] += 1
        self.__ngrams[1][('UNK', )] = 1
        
    @property
    def max_n(self):
        """Get max_n"""
        return self.__max_n
        
    def __getitem__(self, k):
        """Get dictionary of k-gram frequencies.
        Args:
            k (int): length of returning ngrams' frequencies.
        Returns:
            Dictionary (in fact Counter) of k-gram frequencies.
        """
        # Cheking the input
        if not isinstance(k, int):
            raise TypeError('k (length of ngrams) must be an integer!')
        if k > self.__max_n:
            raise ValueError('k (length of ngrams) must be less or equal to the maximal length!')
        return self.__ngrams[k]
    
    def __call__(self, ngram):
        """Return frequency of a given ngram.
        Args:
            ngram (tuple): ngram for which frequency should be computed.    
        Returns:
            Frequency (int) of a given ngram.
        """
        # Cheking the input
        if not isinstance(ngram, tuple):
            raise TypeError('ngram must be a tuple!')
        if len(ngram) > self.__max_n:
            raise ValueError('length of ngram must be less or equal to the maximal length!')
        if len(ngram) == 1 and ngram not in self.__ngrams[1]:
            return self.__ngrams[1][('UNK', )]
        return self.__ngrams[len(ngram)][ngram]

# %%
analyser = pymorphy2.MorphAnalyzer()
stem = RussianStemmer()
morfer = pymorphy2.MorphAnalyzer()

def do_stem(text):
    new_text = ''
    for token in nltk.word_tokenize(text):
        new_text += stem.stem(token) + ' '
    if len(new_text) > 0:
        new_text = new_text[:-1]
    return new_text

# Ищем прилагательные
def find_ADJF(text):
    list_of_ADJF = []
    text = "делал " + text
    tokens = nltk.word_tokenize(text)
    for i in range(1, len(tokens) - 1):
        current_text = ""
        while analyser.parse(tokens[i])[0].tag.POS == 'ADJF' or\
                (analyser.parse(tokens[i - 1])[0].tag.POS == 'CONJ' and\
                 analyser.parse(tokens[i - 1])[0].tag.POS == 'ADJF'):
            current_text += tokens[i] + " "
            i += 1
        if current_text != "":
            if analyser.parse(tokens[i])[0].tag.POS == 'NOUN':
                current_text += tokens[i]
                list_of_ADJF.append(current_text)
    return list_of_ADJF

# Ищем фразы в текстах
def find_frases(text):
    list_of_frases = []
    tokens = nltk.word_tokenize(text)
    for i in range(1, len(tokens) - 1):
        current_text = ""
        while analyser.parse(tokens[i])[0].tag.POS == 'ADJF':
            current_text += tokens[i] + " "
            i += 1
        if current_text != "":
            if analyser.parse(tokens[i])[0].tag.POS == 'NOUN':
                current_text += tokens[i]
                list_of_ADJF.append(current_text)
    return list_of_ADJF
   

# Приводим к нормальной форме слова в текстах
def do_morfy(text):
    new_text = ''
    for token in nltk.word_tokenize(text):
        new_text += morfer.parse(token)[0].normal_form + ' '
    if len(new_text) > 0:
        new_text = new_text[:-1]
    return new_text

# Приводим к нормальной форме существительные в текстах
def do_morfy_nouns(text):
    new_text = ''
    for token in nltk.word_tokenize(text):
        current_token = morfer.parse(token)[0]
        is_noun = current_token.tag.POS == 'NOUN'
        if is_noun:
            new_text += current_token.normal_form + ' '
        else:
            new_text += token + ' '
    if len(new_text) > 0:
        new_text = new_text[:-1]
    return new_text

# Убираем строки, не относящиеся к рассматриваемой категории
def find_product_cat(text):
    for category_cat in products_dict:
        if text in products_dict[category_cat]:
            return category_cat
    return 'Unknown'

# Для нахождения популярных существительных
def nouns_counter(text, count_rate):
    text = re.sub(' и ', ' ', text)
    words_dict = {}
    text = do_morfy(text)
    nouns_count = Counter()
    tokens = nltk.word_tokenize(text)
    for i in range(len(tokens)):
        if analyser.parse(tokens[i])[0].tag.POS == 'NOUN':
            if tokens[i] not in words_dict:
                words_dict[tokens[i]] = Counter()
            nouns_count[tokens[i]] += count_rate
            i_back = i - 1
            i_up = i + 1
            while i_back >= 0 and analyser.parse(tokens[i_back])[0].tag.POS in ['ADJF', 'ADJS']:
                words_dict[tokens[i]][tokens[i_back]] += count_rate
                i_back -= 1
            while i_up < len(tokens) and analyser.parse(tokens[i_up])[0].tag.POS in ['ADJF', 'ADJS']:
                words_dict[tokens[i]][tokens[i_up]] += count_rate
                i_up += 1
    return words_dict, nouns_count

def fill_global_counter(ADJF_c, noun_c, current_ADJF_c, current_noun_c, category):
    for noun in current_ADJF_c:
        if noun not in ADJF_c[category]:
            ADJF_c[category][noun] = Counter()
        for adj in current_ADJF_c[noun]:
            ADJF_c[category][noun][adj] += current_ADJF_c[noun][adj]
    for noun in current_noun_c:
        noun_c[category][noun] += current_noun_c[noun]
    return ADJF_c, noun_c

# %%
text = pd.read_csv('./Base_3.csv', encoding='cp1251', index_col=0, dtype={'Жалобы': str})
text.columns = ['review']
text['len'] = text.review.apply(lambda x: len(str(x)))
text = text[(text['len'] > 120) & (text['len'] < 500)]
text.reset_index(inplace=True)
text.drop('index', axis=1, inplace=True)
text['review'] = text['review'].apply(lambda x: str.lower(str(x)))

# %%
# Находим прилагательные-стопслова и приводим в простую форму
ADJF_stop_words = []
for word in stopwords.words('russian'):
    if morfer.parse(word)[0].tag.POS == 'ADJF':
        ADJF_stop_words.append(morfer.parse(word)[0].normal_form)

# Удаляем прилагательные-стопслова из отзывов
def delete_stop_words(text):
    new_text = ''
    for token in nltk.word_tokenize(text):
        if morfer.parse(token)[0].normal_form not in ADJF_stop_words:
            new_text += token + ' '
    return new_text

text['review'] = text['review'].progress_apply(delete_stop_words)
# Out:
# apply progress bar: 100%|██████████| 60016/60016 [09:57<00:00, 113.13it/s]

# %%
link_table = pd.read_csv('./final_out.csv', index_col=0)
link_table['clear_symptoms'] = link_table['clear_symptoms'].apply(lambda yy: [x[1:-1] for x in yy[1:-1].split(', ')])
link_table['symptoms'] = link_table['symptoms'].apply(lambda yy: [x[1:-1] for x in yy[1:-1].split(', ')])

# %%
link_table = pd.read_csv('./out.csv', index_col=0)
link_table['clear_text'] = link_table['clear_text'].apply(str)
link_table['clear_text'] = link_table['clear_text'].apply(do_morfy)

# %%
text['review'] = text['review'].apply(str)
text['review'] = text['review'].progress_apply(do_morfy)
# Out:
# apply progress bar: 100%|██████████| 60016/60016 [09:48<00:00, 102.01it/s]

# %%
final_list_of_ngrams = []
for ll in text.review.values:
    final_list_of_ngrams.append(nltk.word_tokenize(ll))
storage = NGramStorage(final_list_of_ngrams, 7)
ngrams_jalobi = storage.ret_ngrams()

final_counter_jalobi = Counter()
for i in tqdm_notebook(range(1,8)):
    fff = ngrams_jalobi[i]
    for obj_i in fff.most_common(1000):
        if (',' in obj_i[0]) or ('.' in obj_i[0]) or ('(' in obj_i[0]) or (')' in obj_i[0])\
               or ('-' in obj_i[0]) or ('\'' in obj_i[0]) or (':' in obj_i[0]) or (')' in obj_i[0]):
            pass
        else:
            current_obj_i = ' '.join(list(obj_i[0]))
            final_counter_jalobi[' '.join(list(obj_i[0]))] += obj_i[1]
# Out:
# A Jupyter Widget

# %%
final_list_of_ngrams = []
for ll in link_table.clear_text.values:
    final_list_of_ngrams.append(nltk.word_tokenize(str(ll)))
storage = NGramStorage(final_list_of_ngrams, 7)
ngrams_diseases = storage.ret_ngrams()

final_counter_diseases = Counter()
for i in tqdm_notebook(range(1,8)):
    fff = ngrams_diseases[i]
    for obj_i in fff.most_common(1000):
        if (',' in obj_i[0]) or ('.' in obj_i[0]) or ('(' in obj_i[0]) or (')' in obj_i[0])\
               or ('-' in obj_i[0]) or ('\'' in obj_i[0]) or (':' in obj_i[0]) or (';' in obj_i[0]):
            pass
        else:
            current_obj_i = ' '.join(list(obj_i[0]))
            final_counter_diseases[' '.join(list(obj_i[0]))] += obj_i[1]
# Out:
# A Jupyter Widget

# %%
link_table
# Out:
#                            disease  \
# 0                          Абсцесс
# 1                       Авитаминоз
# 2                       Аденовирус
# 3                 Аденома гипофиза
# 4                 Аденома простаты
# 5        Аденома щитовидной железы
# 6                        Аденомиоз
# 7                         Аднексит
# 8                      Акромегалия
# 9                           Алалия
# 10                      Алкоголизм
# 11                        Аллергия
# 12              Аллергия инсектная
# 13          Аллергия лекарственная
# 14                Аллергия пищевая
# 15                        Алопеция
# 16            Алопеция андрогенная
# 17               Алопеция очаговая
# 18                       Альвеолит
# 19                    Альгоменорея
# 20                       Амблиопия
# 21                        Аменорея
# 22                       Амилоидоз
# 23                         Амнезия
# 24                Анальная трещина
# 25                    Анальный зуд
# 26            Анафилактический шок
# 27                          Ангина
# 28                         Ангиома
# 29    Анемия ( низкий гемоглобин )
# ..                             ...
# 600                         Экзема
# 601                 Экстрасистолия
# 602                Эмфизема легких
# 603                     Эндокардит
# 604                 Эндокринопатии
# 605                    Эндометриоз
# 606                     Эндометрит
# 607                   Эндоцервицит
# 608                        Энтерит
# 609            Энтерит хронический
# 610                     Энтеробиоз
# 611                    Энтероколит
# 612                         Энурез
# 613                      Энцефалит
# 614          Эпидермофития паховая
# 615             Эпидермофития стоп
# 616                     Эпидидимит
# 617                      Эпилепсия
# 618                     Эпителиома
# 619                        Эпифора
# 620                        Эритема
# 621                      Эритразма
# 622             Эрозия шейки матки
# 623                       Эутиреоз
# 624                    Эхинококкоз
# 625  Язва двенадцатиперстной кишки
# 626                   Язва желудка
# 627                 Язвенный колит
# 628                         Ячмень
# 629                           Ящур
#
#                                               fealings  \
# 0    Беспокоящие мысли об обидах, пренебрежении и м...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10   «Кому это надо?» Чувство тщетности, вины, несо...
# 11    Кого вы не выносите? Отрицание собственной силы.
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21    Нежелание быть женщиной. Неприязнь к самой себе.
# 22                                                 NaN
# 23   Страх. Бегство от жизни. Неспособность постоят...
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27   Вы сдерживаетесь от грубых слов. Чувствуете не...
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 600        Непримиримый антагонизм. Психические срывы.
# 601                                                NaN
# 602                                                NaN
# 603                                                NaN
# 604                                                NaN
# 605                                                NaN
# 606                                                NaN
# 607                                                NaN
# 608                                                NaN
# 609                                                NaN
# 610                                                NaN
# 611                                                NaN
# 612               Страх перед родителем, обычно отцом.
# 613                                                NaN
# 614                                                NaN
# 615                                                NaN
# 616                                                NaN
# 617  Мания преследования. Отказ от жизни. Ощущение ...
# 618                                                NaN
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
# 622                                                NaN
# 623                                                NaN
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628  Вы смотрите на жизнь злыми глазами. Злость на ...
# 629                                                NaN
#
#                                               thinking  \
# 0    Я даю мыслям свободу. С прошлым покончено. У м...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10   Я живу в сегодняшнем дне. Каждый момент принос...
# 11   Мир не опасен, он — друг. Мне не грозит никака...
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21   Меня радует, что я такая, какая я есть. Я — эт...
# 22                                                 NaN
# 23   Во мне всегда присутствует разум, смелость и в...
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27   Я отбрасываю все ограничения и обретаю свободу...
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 600  Мир и гармония, любовь и радость окружают меня...
# 601                                                NaN
# 602                                                NaN
# 603                                                NaN
# 604                                                NaN
# 605                                                NaN
# 606                                                NaN
# 607                                                NaN
# 608                                                NaN
# 609                                                NaN
# 610                                                NaN
# 611                                                NaN
# 612  На этого ребенка смотрят с любовью, его жалеют...
# 613                                                NaN
# 614                                                NaN
# 615                                                NaN
# 616                                                NaN
# 617          Отныне я считаю жизнь вечной и радостной.
# 618                                                NaN
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
# 622                                                NaN
# 623                                                NaN
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628       Теперь я смотрю на все с любовью и радостью.
# 629                                                NaN
#
#                                               symptoms  \
# 0    ['резкое повышение температуры (до 40 градусов...
# 1    ['бледная вялая кожа;', 'сухость, раздражение ...
# 2    ['симптомы фарингита (боль в горле, воспаление...
# 3    ['пролактиномы (пролактиновые аденомы);', 'сом...
# 4    ['Обструктивные:- затруднение в процессе мочеи...
# 5    ['возраст пациента старше 40 лет;', 'принадлеж...
# 6    ['испытывающие постоянные стрессы или физическ...
# 7    ['острый аднексит – начальная степень;', 'подо...
# 8    ['увеличение нижней челюсти, скуловых костей, ...
# 9    ['прием медикаментов;', 'физиотерапевтические ...
# 10   ['общий и биохимический анализы крови;', 'общи...
# 11   ['круглогодичной (вызывается аллергенами, дейс...
# 12   ['общий анализ крови;', 'иммунограмму;', 'рино...
# 13   ['длительное и частое применение некоторых\r\n...
# 14   ['насморк;', 'затрудненное дыхание, удушье;', ...
# 15   ['у мужчин волосы истончаются и выпадают в обл...
# 16   ['первичное выпадение волос в лобно-височной о...
# 17   ['активную\r\nалопецию – отличается отечностью...
# 18   ['наследственный фактор;', 'вирусы (вирус герп...
# 19   ['колющие, ноющие, схваткообразные боли, отдаю...
# 20   ['различная оптическая сила у глаз;', 'нарушен...
# 21   ['возрастная – отсутствие месячных при позднем...
# 22   ['генетическая предрасположенность;', 'осложне...
# 23   ['травмы головы;', 'различные болезни (инсульт...
# 24   ['сильную боль в области заднего прохода;', 'с...
# 25   ['сильный зуд в области заднего прохода, усили...
# 26   ['головная боль;', 'боль в грудине;', 'жар;', ...
# 27   ['передачи вируса воздушно-капельным путем;', ...
# 28   ['звездчатыми (точечные ангиоматозные образова...
# 29   ['постгеморрагическая анемия (обусловлена хрон...
# ..                                                 ...
# 600  ['наследственная предрасположенность;', 'гормо...
# 601  ['Предсердные.', 'Желудочковые.', 'Предсердно-...
# 602  ['диффузная эмфизема – поражает все легкие;', ...
# 603  ['изучаются жалобы пациента;', 'назначается эх...
# 604  ['болезнь Шихана;', 'болезнь Симмондса;', 'гип...
# 605  ['I стадия ― патологический процесс локализует...
# 606  ['абортов, миниабортов;', 'родов;', 'диагности...
# 607  ['Острой. Острый эндоцервицит имеет ярко выраж...
# 608  ['поражение кишечника глистами;', 'лямблиоз ки...
# 609  ['тупая боль спастического характера, которая ...
# 610  ['общий осмотр;', 'анализ кала;', 'микроскопич...
# 611  ['острые кишечные инфекции, гельминтоз;', 'алл...
# 612  ['непроизвольное мочеиспускание (в дневное и н...
# 613  ['первичный энцефалит (отсутствие заболевания ...
# 614  ['наличие розовых пятен на коже величиной до 1...
# 615  ['трофические нарушения нижних конечностей;', ...
# 616  ['общий анализ крови;', 'общий анализ мочи;', ...
# 617  ['переутомление;', 'стресс;', 'нарушения сна;'...
# 618  ['длительное пребывание под прямыми солнечными...
# 619  ['блефарит;', 'кератит;', 'конъюнктивит;', 'гл...
# 620  ['инфекционная эритема – интоксикация организм...
# 621  ['пятна на коже с четкими очертаниями красного...
# 622  ['ИППП;', 'механические повреждения шейки (во ...
# 623  ['сильную нервозность, постоянное напряжение;'...
# 624  ['несоблюдение правил личной гигиены;', 'общен...
# 625  ['острая ноющая боль в области желудка;', 'тош...
# 626  ['боль в подложечной части живота, отдающая в ...
# 627  ['жидкий стул с примесью слизи и крови;', 'час...
# 628  ['чужая косметика;', 'грязные щеточки и апплик...
# 629  ['озноб;', 'повышение температуры тела до 39 г...
#
#                                             clear_text  \
# 0    резкий повышение температура до 40 градус ; об...
# 1    бледный вялый кожа ; сухость , раздражение кож...
# 2    симптом фарингит боль в горло , воспаление гор...
# 3    пролактином пролактиновый аденома ; соматотроп...
# 4    обструктивный затруднение в процесс мочеиспуск...
# 5    возраст пациент старший 40 год ; принадлежност...
# 6    испытывать постоянный стресс или физический на...
# 7    острый аднексито – начальный степень ; подостр...
# 8    увеличение нижний челюсть , скуловой кость , н...
# 9    приём медикамент ; физиотерапевтический процед...
# 10   общий и биохимический анализ кровь ; общий ана...
# 11   круглогодичный вызываться аллерген , действующ...
# 12   общий анализ кровь ; иммунограмма ; риноскопия...
# 13   длительный и частый применение некоторый медик...
# 14   насморк ; затруднить дыхание , удушье ; тошнот...
# 15   у мужчина волос истончаться и выпадать в облас...
# 16   первичный выпадение волос в лобновисочный обла...
# 17   активный алопеция – отличаться отёчность и пок...
# 18   наследственный фактор ; вирус вирус герпес , а...
# 19   колющий , ноющий , схваткообразный боль , отда...
# 20   различный оптический сила у глаз ; нарушение о...
# 21   возрастной – отсутствие месячный при поздний п...
# 22   генетический предрасположенность ; осложнение ...
# 23   травма голов ; различный болезнь инсульт , эпи...
# 24   сильный боль в область задний проход ; спазм с...
# 25   сильный зуд в область задний проход , усиливат...
# 26   головной боль ; боль в грудина ; жар ; нитевид...
# 27   передача вирус воздушнокапельный путём ; употр...
# 28   звездчатый точечный ангиоматозный образование ...
# 29   постгеморрагический анемия обусловить хроничес...
# ..                                                 ...
# 600  наследственный предрасположенность ; гормональ...
# 601  предсердный желудочковый предсердножелудочковы...
# 602  диффузный эмфизема – поражать весь лёгкое ; ло...
# 603  изучаться жалоба пациент ; назначаться эхокард...
# 604  болезнь шихан ; болезнь симмондс ; гипофизарны...
# 605  i стадия ― патологический процесс локализовать...
# 606  аборт , миниаборт ; роды ; диагностический выс...
# 607  острый острый эндоцервицит иметь ярко выразить...
# 608  поражение кишечник глист ; лямблиоз кишечник ;...
# 609  тупой боль спастический характер , который лок...
# 610  общий осмотр ; анализ кал ; микроскопический и...
# 611  острый кишечный инфекция , гельминтоз ; аллерг...
# 612  непроизвольный мочеиспускание в дневный и ночн...
# 613  первичный энцефалит отсутствие заболевание как...
# 614  наличие розовый пятно на кожа величина до 1 са...
# 615  трофический нарушение нижний конечность ; вари...
# 616  общий анализ кровь ; общий анализ мочить ; уль...
# 617  переутомление ; стресс ; нарушение сон ; смена...
# 618  длительный пребывание под прямая солнечный луч...
# 619  блефарит ; кератит ; конъюнктивит ; глаукома ;...
# 620  инфекционный эритема – интоксикация организм ,...
# 621  пятно на кожа с чёткий очертание красный , кор...
# 622  ипппа ; механический повреждение шейк в время ...
# 623  сильный нервозность , постоянный напряжение ; ...
# 624  несоблюдение правило личный гигиена ; общение ...
# 625  острый ноющий боль в область желудок ; тошнота...
# 626  боль в подложечный часть живот , отдавать в ле...
# 627  жидкий стул с примесь слизь и кровь ; частый п...
# 628  чужой косметика ; грязный щёточка и аппликатор...
# 629  озноб ; повышение температура тело до 39 граду...
#
#                                                     gg  \
# 0    [('резкий', 27), ('повышение', 59), ('температ...
# 1    [('бледный', 4), ('кожа', 173), ('сухость', 31...
# 2    [('симптом', 22), ('фарингит', 7), ('боль', 25...
# 3    [('аденома', 8), ('аденома', 8), ('аденома', 8...
# 4    [('затруднение', 15), ('в', 766), ('процесс', ...
# 5    [('возраст', 16), ('пациент', 23), ('старший',...
# 6    [('испытывать', 8), ('постоянный', 31), ('стре...
# 7    [('острый', 51), ('–', 172), ('степень', 17), ...
# 8    [('увеличение', 54), ('нижний', 20), ('челюсть...
# 9    [('приём', 34), ('медикамент', 5), ('процедура...
# 10   [('общий', 61), ('и', 448), ('биохимический', ...
# 11   [('вызываться', 4), ('аллерген', 7), ('на', 26...
# 12   [('общий', 61), ('анализ', 19), ('кровь', 56),...
# 13   [('длительный', 41), ('и', 448), ('частый', 57...
# 14   [('насморк', 8), ('затруднить', 8), ('дыхание'...
# 15   [('у', 85), ('мужчина', 9), ('волос', 29), ('и...
# 16   [('первичный', 13), ('выпадение', 21), ('волос...
# 17   [('–', 172), ('отёчность', 26), ('и', 448), ('...
# 18   [('наследственный', 33), ('фактор', 33), ('вир...
# 19   [('ноющий', 9), ('боль', 251), ('отдавать', 11...
# 20   [('различный', 17), ('сила', 6), ('у', 85), ('...
# 21   [('–', 172), ('отсутствие', 27), ('месячный', ...
# 22   [('генетический', 12), ('предрасположенность',...
# 23   [('травма', 66), ('голов', 18), ('различный', ...
# 24   [('сильный', 80), ('боль', 251), ('в', 766), (...
# 25   [('сильный', 80), ('зуд', 41), ('в', 766), ('о...
# 26   [('головной', 76), ('боль', 251), ('боль', 251...
# 27   [('вирус', 30), ('путём', 10), ('употребление'...
# 28   [('образование', 43), ('от', 44), ('который', ...
# 29   [('анемия', 15), ('обусловить', 6), ('кровопот...
# ..                                                 ...
# 600  [('наследственный', 33), ('предрасположенность...
# 601                       [('и', 448), ('узловой', 4)]
# 602  [('диффузный', 6), ('–', 172), ('поражать', 5)...
# 603  [('пациент', 23), ('исследование', 17), ('анал...
# 604  [('болезнь', 44), ('болезнь', 44), ('синдром',...
# 605  [('i', 5), ('стадия', 37), ('патологический', ...
# 606  [('роды', 11), ('полость', 24), ('и', 448), ('...
# 607  [('острый', 51), ('острый', 51), ('иметь', 16)...
# 608  [('поражение', 64), ('кишечник', 13), ('кишечн...
# 609  [('тупой', 6), ('боль', 251), ('характер', 16)...
# 610  [('общий', 61), ('осмотр', 8), ('анализ', 19),...
# 611  [('острый', 51), ('кишечный', 8), ('инфекция',...
# 612  [('непроизвольный', 6), ('мочеиспускание', 48)...
# 613  [('первичный', 13), ('энцефалит', 7), ('отсутс...
# 614  [('наличие', 17), ('розовый', 5), ('пятно', 34...
# 615  [('трофический', 8), ('нарушение', 208), ('ниж...
# 616  [('общий', 61), ('анализ', 19), ('кровь', 56),...
# 617  [('переутомление', 7), ('стресс', 24), ('наруш...
# 618  [('длительный', 41), ('пребывание', 8), ('под'...
# 619  [('конъюнктивит', 6), ('новообразование', 9), ...
# 620  [('инфекционный', 31), ('эритема', 8), ('–', 1...
# 621  [('пятно', 34), ('на', 263), ('кожа', 173), ('...
# 622  [('механический', 11), ('повреждение', 22), ('...
# 623  [('сильный', 80), ('постоянный', 31), ('напряж...
# 624  [('несоблюдение', 8), ('правило', 15), ('личны...
# 625  [('острый', 51), ('ноющий', 9), ('боль', 251),...
# 626  [('боль', 251), ('в', 766), ('часть', 22), ('ж...
# 627  [('жидкий', 6), ('стул', 11), ('с', 179), ('пр...
# 628  [('и', 448), ('для', 31), ('клещ', 5), ('на', ...
# 629  [('озноб', 17), ('повышение', 59), ('температу...
#
#                                         clear_symptoms
# 0    [отёчность и боль при абсцесс поверхностный ти...
# 1    [обострение хронический заболевание рецидив ге...
# 2    [повышение температура тело до 39 градус, восп...
# 3                                            [аденома]
# 4    [обструктивный затруднение в процесс мочеиспус...
# 5    [формирование нетоксический узел в щитовидка, ...
# 6    [испытывать постоянный стресс или физический н...
# 7    [обычно наблюдаться при микозной или туберкулё...
# 8    [изменение прикус появление межзубный промежут...
# 9               [медикамент, процедура, работа, приём]
# 10   [общий и биохимический анализ кровь, биохимиче...
# 11   [сезонный проявляться в время цветение растени...
# 12   [общий анализ кровь, анализ кровь, общий анали...
# 13   [длительный и частый применение некоторый меди...
# 14   [сопровождаться сильный зуд, артериальный давл...
# 15   [мужчина волос истончаться и выпадать в област...
# 16   [первичный выпадение волос в лобновисочный обл...
# 17   [место поражение происходить смешанный рост то...
# 18   [лекарственный препарат и, лекарственный препа...
# 19   [частый позыв к мочеиспускание, повышенный раз...
# 20   [нарушение ориентация в непривычный место и не...
# 21   [внутренний половый орган или проведение специ...
# 22   [осложнение хронический воспалительный заболев...
# 23   [закупорка мелкий артерия головной мозг при ат...
# 24   [кровотечение из задний проход особенно после ...
# 25   [усиливаться в ночное время сутки, зуд в облас...
# 26   [боль в грудина, гиперемия кожа, головной боль...
# 27   [снижение иммунитет, переохлаждение, употребле...
# 28   [высыпание на кожа, высыпание на, образование,...
# 29   [разрушение эритроцит в, являться следствие, в...
# ..                                                 ...
# 600  [наследственный предрасположенность, желудочно...
# 601                                       [узловой, и]
# 602  [образоваться, ограниченный, диффузный, поража...
# 603      [анализ кровь, исследование, пациент, анализ]
# 604                       [ожирение, болезнь, синдром]
# 605  [патологический процесс, слизистый оболочка, л...
# 606   [исследование, и другой, полость, другой, матка]
# 607  [выделение из половый путь, выделение из полов...
# 608  [малоподвижный образ жизнь, аутоиммунный забол...
# 609  [болезненность при пальпация живот, острый бол...
# 610            [исследование, область, анализ, осмотр]
# 611  [пищеварительный система, лекарственный препар...
# 612  [ночное время сутки, температура тело, мочеисп...
# 613  [инфекционный заболевание, инфекционный, забол...
# 614  [очаг поражение, шелушение кожа, пятно на кожа...
# 615  [нижний конечность, недостаточность, атероскле...
# 616  [общий анализ мочить, общий анализ кровь, анал...
# 617  [приём лекарственный препарат, лекарственный п...
# 618  [под прямая солнечный луч, солнечный луч, трав...
# 619                    [новообразование, конъюнктивит]
# 620  [на разгибательный поверхность конечность, пов...
# 621  [зуд в место поражение, в место поражение, мес...
# 622  [изменение гормональный фон, механический повр...
# 623  [повышенный утомляемость, постоянный напряжени...
# 624  [несоблюдение правило личный гигиена, несоблюд...
# 625  [ноющий боль в область желудок, боль в область...
# 626  [боль в область желудок, в область желудок, от...
# 627  [частый позыв к дефекация, повышенный температ...
# 628  [несоблюдение правило личный гигиена, несоблюд...
# 629  [повышение температура тело до 39 градус, повы...
#
# [630 rows x 7 columns]

# %%
link_table[link_table['disease'] == 'Анальная трещина'].symptoms.values
# Out:
# array([ "['сильную боль в области заднего прохода;', 'спазмы сфинктера;', 'кровотечения из заднего прохода (особенно после дефекации);', 'постоянный зуд в области заднего прохода, усиливающийся при ходьбе или после длительного сидения.']"], dtype=object)

# %%
a = 1.6

# %%
def noraml_elem_of_diseases(x):
    x = do_morfy(str(x))
    list_of_symptoms = []
    tokens = nltk.word_tokenize(x)
    for i in range(1, 8):
        for j in range(len(x) - i):
            if ' '.join(tokens[j: j + i]) in final_counter_diseases:
                list_of_symptoms.append((' '.join(tokens[j: j + i]),
                                         final_counter_diseases[' '.join(tokens[j: j + i])]))
    for_return = sorted(list(np.unique([x[0] for x in list_of_symptoms])), key=lambda x : len(x), reverse=True)
    return for_return[:int(len(for_return) / 2) + 1]


def what_disease(link_table, jaloba_mine):
    max_score = 0
    max_disease = ''
    for i in range(link_table.shape[0]):
        current_disease = link_table.iloc[i].disease
        set_symptoms = set(link_table.iloc[i].clear_symptoms)
        set_jaloba = set(jaloba_mine)
        inters = set_jaloba.intersection(set_symptoms)
        score = len(inters) / len(set_jaloba)
        if (score > max_score) & (len(set_symptoms) > 4):
            max_score = score
            max_disease = current_disease
    return score, max_disease

# %%
# jaloba_mine = 'жалуюсь на повышение температуры, общую слабость, отёчность и боль при абсцессе'
jaloba_mine = 'болит живот очень силно тошнит'
jaloba_mine = noraml_elem_of_diseases(jaloba_mine)
score, result = what_disease(link_table, jaloba_mine)
current_tabel = link_table[link_table['disease'] == result]
disease = current_tabel.disease.values[0]
fealings = current_tabel.fealings.values[0]
thinking = current_tabel.thinking.values[0]
symptoms = current_tabel.symptoms.values[0]


text = "Добрый день, я помощник по определению болезни по сырому тексту жалобы.\n"
text += "Введите жалобу в свободном формате (желательно, без ошибок в орфографии)\n"
#process .......
if score == 0.0:
    score = "<0.1"
text += "Ваш ближайший диагноз по описанию: {} с вероятностью {}\n".format(disease, score)
text += "Наблюдается следущая симптоматика:\n"
for i, t in enumerate(symptoms):
    text += str(i + 1) + ') ' + t + '\n'
# text += symptoms
text += '\n'
try:
    np.isnan(fealings)
except:
    text += "Сейчас у вас в голове следущие мысли : "
    text += fealings + '\n'
    text += "Все будет нормально.\nПо дороге к врачу убеждайте себя и повторяйте, что: "
    text += thinking

# %%
print(text)
# Out:
# Добрый день, я помощник по определению болезни по сырому тексту жалобы.
# Введите жалобу в свободном формате (желательно, без ошибок в орфографии)
# Ваш ближайший диагноз по описанию: Целиакия с вероятностью <0.1
# Наблюдается следущая симптоматика:
# 1) потеря веса;
# 2) зловонный жидкий стул;
# 3) увеличение живота в объеме;
# 4) отеки;
# 5) капризност
# 6) аздражительность;
# 7) замедление роста и развития.

# %%
global_noun_ADJF_counter = {'get_cats': {}}
global_noun_counter = {'get_cats': Counter()}

for i in tqdm_notebook(range(text.shape[0])):
    a1, a2 = nouns_counter(text.review[i], 1)
    global_noun_ADJF_counter, global_noun_counter =\
        fill_global_counter(global_noun_ADJF_counter, global_noun_counter, a1, a2, 'get_cats')
# Out:
# A Jupyter Widget

# %%
def find_in_text(texts, global_ADJF, global_nouns):
    nouns_dict = {}
    for noun in tqdm_notebook([nou[0] for nou in global_nouns['get_cats'].most_common()[:100]]):
        current_noun_list = []
        current_ADJF = [adj[0] for adj in global_ADJF['get_cats'][noun].most_common()[:20]]
        for ADJF in current_ADJF:
            rating_list = []
            for i in range(len(texts)):
                if re.search(noun + ' ' + ADJF, texts[i]) or re.search(ADJF + ' ' + noun, texts[i]):
                    rating_list.append(1)
            if len(rating_list) > 0:
                current_noun_list.append((ADJF, rating_list))
        if len(current_noun_list) > 0:
            nouns_dict[noun] = current_noun_list
    return nouns_dict

# %%
gg = find_in_text(text['review'], global_noun_ADJF_counter, global_noun_counter)

# %%
#for normal_text
CneNP = []
neNPC = []
CNP = []
NPC = []
CNGC = []
CNG = []
CneNG = []
PCNP = []
normal_text = text['review']
for j in tqdm_notebook(range(len(normal_text))):
    tokens = nltk.word_tokenize(normal_text[j])
    for i in range(len(tokens) - 3):
        if morfer.parse(tokens[i])[0].tag.POS == 'NOUN' and tokens[i + 1] == 'не' and\
        morfer.parse(tokens[i + 2])[0].tag.POS == 'ADVB' and\
        (morfer.parse(tokens[i + 3])[0].tag.POS == 'ADJF' or morfer.parse(tokens[i + 3])[0].tag.POS == 'ADJS'):
            CneNP.append((morfer.parse(tokens[i])[0].normal_form,
                          tokens[i] + ' ' + tokens[i + 1] + ' ' + tokens[i + 2] + ' ' + tokens[i + 3]))
        elif (morfer.parse(tokens[i])[0].tag.POS == 'ADJF' or morfer.parse(tokens[i])[0].tag.POS == 'ADJS') and\
        morfer.parse(tokens[i + 1])[0].tag.POS == 'NOUN' and\
        morfer.parse(tokens[i + 2])[0].tag.POS == 'ADVB' and\
        (morfer.parse(tokens[i + 3])[0].tag.POS == 'ADJF' or morfer.parse(tokens[i + 3])[0].tag.POS == 'ADJS'):
            if len(tokens[i-1]) > 1 or tokens[i-1] in ['в']:
                PCNP.append((morfer.parse(tokens[i + 1])[0].normal_form,
                            tokens[i-1] + ' ' + tokens[i] + ' ' + tokens[i + 1] + ' ' + tokens[i + 2] + ' ' + tokens[i + 3]))
            else:
                PCNP.append((morfer.parse(tokens[i + 1])[0].normal_form,
                            tokens[i] + ' ' + tokens[i + 1] + ' ' + tokens[i + 2] + ' ' + tokens[i + 3]))
        elif tokens[i] == 'не' and morfer.parse(tokens[i + 1])[0].tag.POS == 'ADVB' and\
        (morfer.parse(tokens[i + 2])[0].tag.POS == 'ADJF' or morfer.parse(tokens[i + 2])[0].tag.POS == 'ADJS') and\
        morfer.parse(tokens[i + 3])[0].tag.POS == 'NOUN':
            neNPC.append((morfer.parse(tokens[i + 3])[0].normal_form,
                          tokens[i] + ' ' + tokens[i + 1] + ' ' + tokens[i + 2] + ' ' + tokens[i + 3]))
        elif morfer.parse(tokens[i])[0].tag.POS == 'NOUN' and\
        morfer.parse(tokens[i + 1])[0].tag.POS == 'ADVB' and\
        (morfer.parse(tokens[i + 2])[0].tag.POS == 'ADJF' or morfer.parse(tokens[i + 2])[0].tag.POS == 'ADJS'):
            CNP.append((morfer.parse(tokens[i])[0].normal_form,
                        tokens[i] + ' ' + tokens[i + 1] + ' ' + tokens[i + 2]))
        elif morfer.parse(tokens[i])[0].tag.POS == 'ADVB' and\
        (morfer.parse(tokens[i + 1])[0].tag.POS == 'ADJF' or morfer.parse(tokens[i + 1])[0].tag.POS == 'ADJS') and\
        morfer.parse(tokens[i + 2])[0].tag.POS == 'NOUN':
            NPC.append((morfer.parse(tokens[i + 2])[0].normal_form,
                        tokens[i] + ' ' + tokens[i + 1] + ' ' + tokens[i + 2]))
        elif morfer.parse(tokens[i])[0].tag.POS == 'NOUN' and\
            morfer.parse(tokens[i + 1])[0].tag.POS == 'ADVB' and\
            (morfer.parse(tokens[i + 2])[0].tag.POS == 'INFN' or morfer.parse(tokens[i + 2])[0].tag.POS == 'VERB') and\
            morfer.parse(tokens[i + 3])[0].tag.POS == 'NOUN':
                CNGC.append((morfer.parse(tokens[i])[0].normal_form,
                             tokens[i] + ' ' + tokens[i + 1] + ' ' + tokens[i + 2] + ' ' + tokens[i + 3]))
        elif morfer.parse(tokens[i])[0].tag.POS == 'NOUN' and\
        morfer.parse(tokens[i + 1])[0].tag.POS == 'ADVB' and\
        (morfer.parse(tokens[i + 2])[0].tag.POS == 'INFN' or morfer.parse(tokens[i + 2])[0].tag.POS == 'VERB'):
            CNG.append((morfer.parse(tokens[i])[0].normal_form,
                        tokens[i] + ' ' + tokens[i + 1] + ' ' + tokens[i + 2]))
        elif morfer.parse(tokens[i])[0].tag.POS == 'NOUN' and tokens[i + 1] == 'не' and\
        morfer.parse(tokens[i + 2])[0].tag.POS == 'ADVB' and\
        (morfer.parse(tokens[i + 3])[0].tag.POS == 'INFN' or morfer.parse(tokens[i + 3])[0].tag.POS == 'VERB'):
            CneNG.append((morfer.parse(tokens[i])[0].normal_form,
                          tokens[i] + ' ' + tokens[i + 1] + ' ' + tokens[i + 2] + ' ' + tokens[i + 3]))
